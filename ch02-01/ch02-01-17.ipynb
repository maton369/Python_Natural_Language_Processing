# %%
# リスト 2.1.17
# Webページのデータ読み込み（requests + BeautifulSoup を用いた最小例）
# ------------------------------------------------------------------------------------------------
# 目的:
#   - HTTP GET で HTML を取得し、BeautifulSoup で DOM をパースして解析の出発点となるオブジェクトを得る。
#
# 背景・理論メモ（コメントのみで挙動は変更しない）:
#   - HTTP クライアント: `requests.get` はデフォルトで TLS 検証あり（verify=True）。実運用では
#     タイムアウト（timeout=…）、再試行、適切な User-Agent の明示が推奨される。
#   - ステータス検査: 本スニペットでは最小例として status code を確認していない。堅牢化するなら
#     2xx 以外のハンドリング（例外/リトライ）を入れるのが一般的。
#   - 文字エンコーディング: `response.content` は「生バイト列」。`response.text` は
#     推定エンコーディングを通した文字列。Yahoo! JAPAN は UTF-8 だが、一般化するなら
#     `response.apparent_encoding` を使う選択肢もある（ここでは挙動を変えない）。
#   - パーサ選択: `"html.parser"` は標準ライブラリで依存が増えない一方、速度・寛容性は `lxml`
#     や `html5lib` に劣る場合がある。大規模クロールでは `lxml` がよく用いられる。
#   - 動的レンダリング: ニュースポータルはクライアント側で追加ロードされる要素（XHR/JS）もある。
#     本例は「初期 HTML の静的部分」だけが対象になる点に注意（Selenium/Playwright を使うと動的要素にも対応可）。
#   - 法的/倫理面: 利用規約・robots.txt・レート制御（sleep/Backoff）・アクセス頻度は順守すること。
#     研究/教育目的でも出力の再配布や大量取得には配慮が必要。
# ------------------------------------------------------------------------------------------------

import requests
from bs4 import BeautifulSoup

# Yahoo ニュースサイトのトップページ URL（静的 HTML の先頭部分のみ取得する最小例）
url = "https://news.yahoo.co.jp"

# HTTP GET を実行して HTML を取得
# - 本例では timeout やヘッダ（User-Agent）を省略している。実運用では追加を推奨。
# - 失敗時（例: 403, 429, 5xx）やネットワーク例外の捕捉は省略（最小例）。
html = requests.get(url)

# BeautifulSoup で HTML をパースして DOM ライクなオブジェクトへ変換
# - 第1引数に生バイト列（response.content）を渡すと、内部で自動デコードが行われる
# - パーサ "html.parser" は標準実装。速度重視なら "lxml" を選ぶことも多い（別途依存が必要）。
contents = BeautifulSoup(html.content, "html.parser")

# %%
# リスト 2.1.18
# サイトの情報確認（BeautifulSoup オブジェクトの直列化出力）
# --------------------------------------------------------------------------------
# 目的:
#   - 直前にパースした BeautifulSoup オブジェクト `contents` を、そのまま標準出力へ書き出して
#     取得済み HTML の構造や内容を目視確認する。
#
# 理論・背景（挙動は変えずに説明のみ）:
#   - print(contents) は、BeautifulSoup オブジェクトの __str__()（= 文字列化）を呼び出す。
#     これは「現在のパース木を HTML として再シリアライズした文字列」を返す。
#     ※ 重要: これは「元のレスポンスの生バイト列」ではなく、「パーサが正規化した後のマークアップ」。
#        つまり、属性順序や空白、欠落タグの自動補完などが起きるため、原文と完全一致はしない。
#   - パーサ依存性:
#       * "html.parser" は標準の寛容パーサで、軽量・依存少なめだが、`lxml` 等と比べて
#         正規化の結果やタグ修復の挙動が異なる。従って print(contents) の見た目は
#         パーサ選択に依存して変化し得る（決定性に影響）。
#   - 出力サイズと可観測性:
#       * トップページのような大規模 HTML をそのまま出力すると非常に長くなり、ログが読みにくい。
#         目視 EDA 用には `print(contents.prettify()[:2000])`（先頭のみ）や
#         `print(contents.title)`（<title> 要素のみ）などのプローブ出力が実務的。
#         ※ 本スニペットでは挙動を変えないため、そのまま全量出力にしている。
#   - DOM vs. レンダリング結果:
#       * ここで得ているのは「初期 HTML の静的部分」のパース木であり、ブラウザでの
#         追加レンダリング（JS による要素注入）結果ではない。動的に生成される
#         記事一覧等は含まれない可能性がある点に注意。
#   - 再現性と監査可能性:
#       * Yahoo!トップは時変データであり、取得時刻・User-Agent・地域設定により内容が変化する。
#         再現性が重要な場合、レスポンスのハッシュ（SHA-256）や取得時刻、HTTP ヘッダを
#         併せて保存するのが理にかなう（ここでは最小例のため省略）。
#
# 補足（代替出力例: 実装は変えずコメントのみ）:
#   - `print(contents.prettify())` : インデント付きで階層を把握しやすい
#   - `print(contents.title.string)` : タイトル文字列だけ確認
#   - `for a in contents.select('a'): print(a.get('href'))` : リンク一覧の抽出
#   これらは目的ごとに情報量を制御でき、ログ汚染を避けやすい。
#
# 注意:
#   - `contents` が None の場合は何も出力されない（通常は BeautifulSoup(...) が必ずオブジェクトを返す）。
#   - 文字化けがある場合は、requests 側のエンコーディング推定や `html = requests.get(...); html.encoding = 'utf-8'`
#     の明示、もしくは `BeautifulSoup(html.text, ...)` の利用を検討する。

print(contents)
# Out:
# <!DOCTYPE html>
# <!DOCTYPE html>
# <html lang="ja"><head><title>Yahoo!ニュース</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=1010" name="viewport"/><meta content="text/css" http-equiv="Content-Style-Type"/><meta content="text/javascript" http-equiv="Content-Script-Type"/><meta content="Yahoo!ニュースは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事など多種多様なニュースを掲載しています。" name="description"/><meta content="noarchive, max-image-preview:large" name="robots"/><meta content="telephone=no" name="format-detection"/><meta content="dVyTbsDzUrUAjCE1aCH9hKwZ8sOsCsvi2uhuBvasrp8" name="google-site-verification"/><meta content="Yahoo!ニュース" property="og:site_name"/><meta content="https://s.yimg.jp/images/news-web/versions/20251110-72f866c/all/images/ogp_default.png" property="og:image"/><meta content="Yahoo!ニュースは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事など多種多様なニュースを掲載しています。" property="og:description"/><meta content="Yahoo!ニュース" property="og:title"/><meta content="website" property="og:type"/><meta content="https://news.yahoo.co.jp/" property="og:url"/><meta content="ja_JP" property="og:locale"/><meta content="https://s.yimg.jp/c/icon/s/bsc/2.0/news144.png" name="msapplication-TileImage"/><meta content="#FFFFFF" name="msapplication-TileColor"/><meta content="276725822409153" property="fb:app_id"/><meta content="Yahoo!ニュースは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事など多種多様なニュースを掲載しています。" name="twitter:description"/><meta content="https://s.yimg.jp/images/news-web/versions/20251110-72f866c/all/images/ogp_default.png" name="twitter:image"/><meta content="summary_large_image" name="twitter:card"/><meta content="Yahoo!ニュース" name="twitter:title"/><meta content="@YahooNewsTopics" name="twitter:site"/><meta content="23622BF224ED75EAF67061E9A6003026" name="msvalidate.01"/><meta content="jp" name="twitter:app:country"/><meta content="Yahoo!ニュース" name="twitter:app:name:iphone"/><meta content="407906756" name="twitter:app:id:iphone"/><meta content="yjnews://l/top/" name="twitter:app:url:iphone"/><meta content="Yahoo!ニュース" name="twitter:app:name:googleplay"/><meta content="jp.co.yahoo.android.news" name="twitter:app:id:googleplay"/><meta content="yjnews://l/top/" name="twitter:app:url:googleplay"/><meta content="Yahoo!ニュース" property="al:ios:app_name"/><meta content="407906756" property="al:ios:app_store_id"/><meta content="yjnews://l/top/" property="al:ios:url"/><meta content="Yahoo!ニュース" property="al:android:app_name"/><meta content="jp.co.yahoo.android.news" property="al:android:package"/><link href="https://news.yahoo.co.jp/" rel="canonical"/><link href="https://s.yimg.jp/c/icon/s/bsc/2.0/news120.png" rel="apple-touch-icon-precomposed"/><link href="https://s.yimg.jp/c/icon/s/bsc/2.0/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link href="https://s.yimg.jp/images/news-web/versions/20251110-72f866c/pc/css/common.css" rel="stylesheet"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"WebSite","url":"https://news.yahoo.co.jp","potentialAction":{"@type":"SearchAction","target":"https://news.yahoo.co.jp/search?p={search_term_string}&ei=utf-8","query-input":"required name=search_term_string"}}</script><style data-styled="" data-styled-version="5.3.1">.hKKRl{padding:12px 0 20px;font-size:0.7499999999999999rem;line-height:1.6;text-align:center;background-color:#FFFFFF;}/*!sc*/
# data-styled.g1[id="sc-q9fg9u-0"]{content:"hKKRl,"}/*!sc*/
# .fyKMIm:visited{color:#663399;}/*!sc*/
# .fyKMIm:hover{color:#CC3434;}/*!sc*/
# data-styled.g2[id="sc-q9fg9u-1"]{content:"fyKMIm,"}/*!sc*/
# .ggjbER{width:990px;padding:12px;margin:auto;background-color:#4E555D;}/*!sc*/
# data-styled.g3[id="sc-15iia5a-0"]{content:"ggjbER,"}/*!sc*/
# .jyROQm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0 -8px;}/*!sc*/
# data-styled.g4[id="sc-15iia5a-1"]{content:"jyROQm,"}/*!sc*/
# .kirrbq{width:25%;padding:0 8px;}/*!sc*/
# data-styled.g5[id="sc-15iia5a-2"]{content:"kirrbq,"}/*!sc*/
# .cGrbcu{position:relative;display:block;height:100%;min-height:56px;padding:8px 56px 8px 8px;background-color:#494E54;border:1px #3C4147 solid;}/*!sc*/
# .cGrbcu:hover{-webkit-text-decoration:none;text-decoration:none;opacity:0.8;}/*!sc*/
# .cGrbcu::after{position:absolute;top:0;right:8px;bottom:0;display:block;width:40px;height:40px;margin:auto;content:'';background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/pc/images/spr_footerNavigation_icon_v2.png);background-repeat:no-repeat;background-size:auto 40px;background-position:calc(-40px * 0) 0;}/*!sc*/
# .hlpKMv{position:relative;display:block;height:100%;min-height:56px;padding:8px 56px 8px 8px;background-color:#494E54;border:1px #3C4147 solid;}/*!sc*/
# .hlpKMv:hover{-webkit-text-decoration:none;text-decoration:none;opacity:0.8;}/*!sc*/
# .hlpKMv::after{position:absolute;top:0;right:8px;bottom:0;display:block;width:40px;height:40px;margin:auto;content:'';background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/pc/images/spr_footerNavigation_icon_v2.png);background-repeat:no-repeat;background-size:auto 40px;background-position:calc(-40px * 1) 0;}/*!sc*/
# .hbgGFc{position:relative;display:block;height:100%;min-height:56px;padding:8px 56px 8px 8px;background-color:#494E54;border:1px #3C4147 solid;}/*!sc*/
# .hbgGFc:hover{-webkit-text-decoration:none;text-decoration:none;opacity:0.8;}/*!sc*/
# .hbgGFc::after{position:absolute;top:0;right:8px;bottom:0;display:block;width:40px;height:40px;margin:auto;content:'';background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/pc/images/spr_footerNavigation_icon_v2.png);background-repeat:no-repeat;background-size:auto 40px;background-position:calc(-40px * 2) 0;}/*!sc*/
# .qJGQh{position:relative;display:block;height:100%;min-height:56px;padding:8px 56px 8px 8px;background-color:#494E54;border:1px #3C4147 solid;}/*!sc*/
# .qJGQh:hover{-webkit-text-decoration:none;text-decoration:none;opacity:0.8;}/*!sc*/
# .qJGQh::after{position:absolute;top:0;right:8px;bottom:0;display:block;width:40px;height:40px;margin:auto;content:'';background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/pc/images/spr_footerNavigation_icon_v2.png);background-repeat:no-repeat;background-size:auto 40px;background-position:calc(-40px * 3) 0;}/*!sc*/
# data-styled.g6[id="sc-15iia5a-3"]{content:"cGrbcu,hlpKMv,hbgGFc,qJGQh,"}/*!sc*/
# .gNmSvt{display:block;font-size:0.8749999999999999rem;font-weight:bold;color:#FFFFFF;}/*!sc*/
# data-styled.g7[id="sc-15iia5a-4"]{content:"gNmSvt,"}/*!sc*/
# .cPfEqq{display:block;margin-top:4px;font-size:0.7499999999999999rem;line-height:1.2;color:#DBDBDB;}/*!sc*/
# data-styled.g8[id="sc-15iia5a-5"]{content:"cPfEqq,"}/*!sc*/
# .gbDzA-d{margin:12px 20px 0;font-size:0.8125rem;}/*!sc*/
# data-styled.g9[id="sc-15iia5a-6"]{content:"gbDzA-d,"}/*!sc*/
# .YgUuy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g10[id="sc-15iia5a-7"]{content:"YgUuy,"}/*!sc*/
# .sc-15iia5a-8 + .sc-15iia5a-8{border-left:1px #3C4147 solid;}/*!sc*/
# data-styled.g11[id="sc-15iia5a-8"]{content:"dOlPDB,"}/*!sc*/
# .leRuGi{display:block;padding:0 10px;color:#FFFFFF;}/*!sc*/
# .leRuGi:hover{color:#FFFFFF;}/*!sc*/
# data-styled.g12[id="sc-15iia5a-9"]{content:"leRuGi,"}/*!sc*/
# .gzBYYA{margin-top:20px;}/*!sc*/
# data-styled.g13[id="sc-1ipqdtj-0"]{content:"gzBYYA,"}/*!sc*/
# .bfTAVr{position:relative;margin-right:4px;}/*!sc*/
# data-styled.g18[id="sc-1a5izri-0"]{content:"bfTAVr,"}/*!sc*/
# .GIdOR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:316px;margin:8px 12px;}/*!sc*/
# data-styled.g19[id="sc-1a5izri-1"]{content:"GIdOR,"}/*!sc*/
# .erlYiR{position:relative;background-color:#FFFFFF;border:1px solid #BBBBBB;border-right:none;border-radius:3px 0 0 3px;}/*!sc*/
# .erlYiR::after{position:absolute;top:50%;right:0;display:block;height:12px;content:'';border-right:1px solid #BBBBBB;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);}/*!sc*/
# data-styled.g20[id="sc-1a5izri-2"]{content:"erlYiR,"}/*!sc*/
# .jaNIIv{width:282px;height:26px;padding-left:4px;font-size:0.7499999999999999rem;line-height:26px;border-radius:3px 0 0 3px;}/*!sc*/
# .jaNIIv::-webkit-input-placeholder{color:rgb(0 0 0 / 43%);}/*!sc*/
# .jaNIIv::-moz-placeholder{color:rgb(0 0 0 / 43%);}/*!sc*/
# .jaNIIv:-ms-input-placeholder{color:rgb(0 0 0 / 43%);}/*!sc*/
# .jaNIIv::placeholder{color:rgb(0 0 0 / 43%);}/*!sc*/
# data-styled.g21[id="sc-1a5izri-3"]{content:"jaNIIv,"}/*!sc*/
# .lplCjf{background-color:#FFFFFF;border:1px solid #BBBBBB;border-left:none;border-radius:0 3px 3px 0;}/*!sc*/
# data-styled.g22[id="sc-1a5izri-4"]{content:"lplCjf,"}/*!sc*/
# .igZwvK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:26px;padding:0 8px;cursor:pointer;}/*!sc*/
# data-styled.g23[id="sc-1a5izri-5"]{content:"igZwvK,"}/*!sc*/
# .dONbjh{color:#444444;}/*!sc*/
# data-styled.g24[id="sc-1a5izri-6"]{content:"dONbjh,"}/*!sc*/
# .gJIhOe{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gJIhOe:hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g25[id="sc-1mps4g6-0"]{content:"gJIhOe,"}/*!sc*/
# .gULBmj{margin:0 auto;}/*!sc*/
# data-styled.g26[id="sc-1mps4g6-1"]{content:"gULBmj,"}/*!sc*/
# .flgkZr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .flgkZr .sc-1mps4g6-0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.7499999999999999rem;color:#333333;-webkit-text-decoration:none;text-decoration:none;border-left:1px solid #E1E1E1;padding:0 10px;}/*!sc*/
# .flgkZr .sc-1mps4g6-0:hover{-webkit-text-decoration:underline;text-decoration:underline;background-color:#fff;}/*!sc*/
# .iansBY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .iansBY .sc-1mps4g6-0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.7499999999999999rem;color:#333333;-webkit-text-decoration:none;text-decoration:none;border-left:1px solid #E1E1E1;padding:0 20px;}/*!sc*/
# .iansBY .sc-1mps4g6-0:hover{-webkit-text-decoration:underline;text-decoration:underline;background-color:#fff;}/*!sc*/
# .lfapxT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .lfapxT .sc-1mps4g6-0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.7499999999999999rem;color:#333333;-webkit-text-decoration:none;text-decoration:none;border-left:1px solid #E1E1E1;width:46px;}/*!sc*/
# .lfapxT .sc-1mps4g6-0:hover{-webkit-text-decoration:underline;text-decoration:underline;background-color:#fff;}/*!sc*/
# .hkMhsE{font-size:0.8749999999999999rem;text-shadow:0 1px 0 rgb(0 0 0 / 30%);box-shadow:1px 0 0 rgb(255 255 255 / 8%);}/*!sc*/
# .hkMhsE:hover{box-shadow:none;}/*!sc*/
# .hkMhsE .sc-1mps4g6-0{display:block;padding:8px 20px;line-height:22px;color:#fff;border-right:1px #3a6181 solid;background:#404552;border-right:1px #3a3e49 solid;}/*!sc*/
# .hkMhsE .sc-1mps4g6-0:hover{background-color:#5590b5;border-right:1px #3a6181 solid;-webkit-transition:all 0.2s;transition:all 0.2s;}/*!sc*/
# .kMKDnI{font-size:0.8749999999999999rem;text-shadow:0 1px 0 rgb(0 0 0 / 30%);box-shadow:1px 0 0 rgb(255 255 255 / 8%);}/*!sc*/
# .kMKDnI:hover{box-shadow:none;}/*!sc*/
# .kMKDnI .sc-1mps4g6-0{display:block;padding:8px 20px;line-height:22px;color:#fff;border-right:1px #3a6181 solid;}/*!sc*/
# .kMKDnI .sc-1mps4g6-0:hover{background-color:#5590b5;border-right:1px #3a6181 solid;-webkit-transition:all 0.2s;transition:all 0.2s;}/*!sc*/
# .jdNgkV{position:relative;padding:0 8px;font-size:0.8749999999999999rem;}/*!sc*/
# .jdNgkV:not(:first-of-type)::before{position:absolute;top:50%;left:0;display:block;width:1px;height:14px;margin-top:-7px;content:'';background-color:#E1E1E1;}/*!sc*/
# .jdNgkV .sc-1mps4g6-0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;min-width:calc(2em + 16px);height:40px;padding:0 8px;font-weight:bold;line-height:40px;color:#4e5665;border-bottom:0 solid #476e9a;-webkit-transition:border-width 0.1s ease-in-out;transition:border-width 0.1s ease-in-out;color:#131924;border-bottom-width:4px;}/*!sc*/
# .jdNgkV .sc-1mps4g6-0:hover{color:#131924;border-bottom-width:4px;}/*!sc*/
# .fUsYny{position:relative;padding:0 8px;font-size:0.8749999999999999rem;}/*!sc*/
# .fUsYny:not(:first-of-type)::before{position:absolute;top:50%;left:0;display:block;width:1px;height:14px;margin-top:-7px;content:'';background-color:#E1E1E1;}/*!sc*/
# .fUsYny .sc-1mps4g6-0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;min-width:calc(2em + 16px);height:40px;padding:0 8px;font-weight:bold;line-height:40px;color:#4e5665;border-bottom:0 solid #476e9a;-webkit-transition:border-width 0.1s ease-in-out;transition:border-width 0.1s ease-in-out;}/*!sc*/
# .fUsYny .sc-1mps4g6-0:hover{color:#131924;border-bottom-width:4px;}/*!sc*/
# data-styled.g27[id="sc-1mps4g6-2"]{content:"flgkZr,iansBY,lfapxT,hkMhsE,kMKDnI,jdNgkV,fUsYny,"}/*!sc*/
# .ijuFgx{position:relative;width:990px;margin:0 auto;}/*!sc*/
# data-styled.g31[id="sc-icb4tv-0"]{content:"ijuFgx,"}/*!sc*/
# .hdfiKA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;background-color:#F7F7F7;border-top:1px solid #E1E1E1;}/*!sc*/
# data-styled.g32[id="sc-icb4tv-1"]{content:"hdfiKA,"}/*!sc*/
# .eSeojU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g33[id="sc-icb4tv-2"]{content:"eSeojU,"}/*!sc*/
# .fvOJzU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#44739c;background-image:linear-gradient(to bottom,#44739c,#436f92);}/*!sc*/
# data-styled.g35[id="sc-icb4tv-4"]{content:"fvOJzU,"}/*!sc*/
# .cKQsQe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-left:5px;background:#fff;border-bottom:1px #E1E1E1 solid;}/*!sc*/
# data-styled.g37[id="sc-icb4tv-6"]{content:"cKQsQe,"}/*!sc*/
# .bsmKsJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g38[id="sc-icb4tv-7"]{content:"bsmKsJ,"}/*!sc*/
# .eDNJiS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:990px;padding:12px 10px;margin:0 auto;background:#FFFFFF;border-bottom:1px solid #F0F0F0;}/*!sc*/
# data-styled.g39[id="sc-wyepu0-0"]{content:"eDNJiS,"}/*!sc*/
# .bEDLqp{display:block;}/*!sc*/
# data-styled.g40[id="sc-wyepu0-1"]{content:"bEDLqp,"}/*!sc*/
# .kZUXoC{width:206px;height:34px;}/*!sc*/
# data-styled.g41[id="sc-wyepu0-2"]{content:"kZUXoC,"}/*!sc*/
# .cEtrIL{display:block;}/*!sc*/
# data-styled.g42[id="sc-wyepu0-3"]{content:"cEtrIL,"}/*!sc*/
# .jviMvu{padding-left:8px;font-size:0.8749999999999999rem;color:#0033CC;}/*!sc*/
# data-styled.g43[id="sc-wyepu0-4"]{content:"jviMvu,"}/*!sc*/
# .NxFLs{width:990px;margin:0 auto;}/*!sc*/
# data-styled.g44[id="sc-qccjvf-0"]{content:"NxFLs,"}/*!sc*/
# .kVywcd{background-color:#FFFFFF;}/*!sc*/
# .kVywcd #emg{width:990px;margin:0 auto;}/*!sc*/
# data-styled.g45[id="sc-qi0cuu-0"]{content:"kVywcd,"}/*!sc*/
# .gInhqu{-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);height:1px;overflow:hidden;position:absolute !important;width:1px;}/*!sc*/
# data-styled.g46[id="sc-qi0cuu-1"]{content:"gInhqu,"}/*!sc*/
# .iMLphd{min-width:990px;}/*!sc*/
# data-styled.g47[id="sc-1ofrwxp-0"]{content:"iMLphd,"}/*!sc*/
# .jNMkif{background-color:#F7F7F7;}/*!sc*/
# data-styled.g48[id="sc-1ofrwxp-1"]{content:"jNMkif,"}/*!sc*/
# .LkLlX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:990px;margin:0 auto;}/*!sc*/
# .LkLlX.contents-hasOneColumn{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .LkLlX.contents-hasOneColumn #yjnMain{min-width:auto;}/*!sc*/
# .LkLlX #yjnMain{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0;max-width:674px;}/*!sc*/
# .LkLlX #yjnMain.oneColumn{max-width:none;}/*!sc*/
# .LkLlX *::-ms-backdrop,.LkLlX #yjnMain{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;width:674px;}/*!sc*/
# data-styled.g49[id="sc-1ofrwxp-2"]{content:"LkLlX,"}/*!sc*/
# .fnDUAa{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0;max-width:674px;}/*!sc*/
# .fnDUAa *::-ms-backdrop{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;width:674px;}/*!sc*/
# data-styled.g50[id="sc-ea06qp-0"]{content:"fnDUAa,"}/*!sc*/
# .iHohtA{margin-top:-1px;background-color:#FFFFFF;border:1px solid #E1E1E1;}/*!sc*/
# data-styled.g51[id="sc-ea06qp-1"]{content:"iHohtA,"}/*!sc*/
# .eYOuBK{width:auto;margin:12px 16px;word-break:break-all;}/*!sc*/
# data-styled.g52[id="sc-1vhlgry-0"]{content:"eYOuBK,"}/*!sc*/
# .kSCKqG{display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:40px;height:40px;margin-right:8px;background-image:url(https://s.yimg.jp/images/news-fe-ops/notice/img/pr_102x102.png);background-repeat:no-repeat;background-position:left center;background-size:contain;}/*!sc*/
# data-styled.g60[id="sc-i69s-0"]{content:"kSCKqG,"}/*!sc*/
# .glwAQq{width:100%;font-size:0.8749999999999999rem;line-height:1.3;}/*!sc*/
# data-styled.g61[id="sc-i69s-1"]{content:"glwAQq,"}/*!sc*/
# .hwhIyC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;padding:8px 0;border-bottom:1px solid #E1E1E1;}/*!sc*/
# .hwhIyC:visited .sc-i69s-1{color:#663399;}/*!sc*/
# .hwhIyC:hover{-webkit-text-decoration:none;text-decoration:none;background-color:#EAEEF2;}/*!sc*/
# .hwhIyC:hover .sc-i69s-1{color:#CC3434;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g63[id="sc-i69s-3"]{content:"hwhIyC,"}/*!sc*/
# .igFNid{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# data-styled.g64[id="sc-i69s-4"]{content:"igFNid,"}/*!sc*/
# .juGdlM{width:100%;margin-top:4px;font-size:0.7499999999999999rem;line-height:1.3;color:#666666;}/*!sc*/
# data-styled.g65[id="sc-i69s-5"]{content:"juGdlM,"}/*!sc*/
# .hhXGul{padding-bottom:16px;border-top:1px solid #E1E1E1;}/*!sc*/
# data-styled.g67[id="sc-1er37uk-0"]{content:"hhXGul,"}/*!sc*/
# .pFymB .yads_ad_pc,.pFymB .yads_ad_pc_res_s,.pFymB .yads_ad_pc_rank,.pFymB .yads_ad_pc_rank_res_s{position:relative;margin-bottom:15px;border-bottom:1px solid #E1E1E1;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_item,.pFymB .yads_ad_pc_res_s .yads_ad_item,.pFymB .yads_ad_pc_rank .yads_ad_item,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item,.pFymB .yads_ad_pc .yads_ad_item_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_item_res_s,.pFymB .yads_ad_pc_rank .yads_ad_item_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item_res_s{display:block;padding:8px 0 24px;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_item:hover,.pFymB .yads_ad_pc_res_s .yads_ad_item:hover,.pFymB .yads_ad_pc_rank .yads_ad_item:hover,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item:hover,.pFymB .yads_ad_pc .yads_ad_item_res_s:hover,.pFymB .yads_ad_pc_res_s .yads_ad_item_res_s:hover,.pFymB .yads_ad_pc_rank .yads_ad_item_res_s:hover,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item_res_s:hover{-webkit-text-decoration:none;text-decoration:none;background:#EAEEF2;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_item:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_item:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc_rank .yads_ad_item:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc .yads_ad_item_res_s:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_item_res_s:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc_rank .yads_ad_item_res_s:hover .yads_ad_title_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item_res_s:hover .yads_ad_title_res_s{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_item::after,.pFymB .yads_ad_pc_res_s .yads_ad_item::after,.pFymB .yads_ad_pc_rank .yads_ad_item::after,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item::after,.pFymB .yads_ad_pc .yads_ad_item_res_s::after,.pFymB .yads_ad_pc_res_s .yads_ad_item_res_s::after,.pFymB .yads_ad_pc_rank .yads_ad_item_res_s::after,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item_res_s::after{content:'';clear:both;display:block;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_img,.pFymB .yads_ad_pc_res_s .yads_ad_img,.pFymB .yads_ad_pc_rank .yads_ad_img,.pFymB .yads_ad_pc_rank_res_s .yads_ad_img,.pFymB .yads_ad_pc .yads_ad_img_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_img_res_s,.pFymB .yads_ad_pc_rank .yads_ad_img_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_img_res_s{float:right;width:60px;height:60px;margin:0 0 0 8px;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_img img,.pFymB .yads_ad_pc_res_s .yads_ad_img img,.pFymB .yads_ad_pc_rank .yads_ad_img img,.pFymB .yads_ad_pc_rank_res_s .yads_ad_img img,.pFymB .yads_ad_pc .yads_ad_img_res_s img,.pFymB .yads_ad_pc_res_s .yads_ad_img_res_s img,.pFymB .yads_ad_pc_rank .yads_ad_img_res_s img,.pFymB .yads_ad_pc_rank_res_s .yads_ad_img_res_s img{max-width:60px;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_desc,.pFymB .yads_ad_pc_res_s .yads_ad_desc,.pFymB .yads_ad_pc_rank .yads_ad_desc,.pFymB .yads_ad_pc_rank_res_s .yads_ad_desc,.pFymB .yads_ad_pc .yads_ad_desc_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_desc_res_s,.pFymB .yads_ad_pc_rank .yads_ad_desc_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_desc_res_s,.pFymB .yads_ad_pc .yads_ad_title,.pFymB .yads_ad_pc_res_s .yads_ad_title,.pFymB .yads_ad_pc_rank .yads_ad_title,.pFymB .yads_ad_pc_rank_res_s .yads_ad_title,.pFymB .yads_ad_pc .yads_ad_title_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_title_res_s,.pFymB .yads_ad_pc_rank .yads_ad_title_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_title_res_s{font-size:82.5%;word-wrap:break-word;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_adv,.pFymB .yads_ad_pc_res_s .yads_ad_adv,.pFymB .yads_ad_pc_rank .yads_ad_adv,.pFymB .yads_ad_pc_rank_res_s .yads_ad_adv,.pFymB .yads_ad_pc .yads_ad_adv_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_adv_res_s,.pFymB .yads_ad_pc_rank .yads_ad_adv_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_adv_res_s{font-size:0.7499999999999999rem;color:#949494;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_info,.pFymB .yads_ad_pc_res_s .yads_ad_info,.pFymB .yads_ad_pc_rank .yads_ad_info,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info,.pFymB .yads_ad_pc .yads_ad_info_res_s,.pFymB .yads_ad_pc_res_s .yads_ad_info_res_s,.pFymB .yads_ad_pc_rank .yads_ad_info_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info_res_s{position:absolute;right:0;bottom:4px;font-size:0.6875rem;line-height:14px;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_info a,.pFymB .yads_ad_pc_res_s .yads_ad_info a,.pFymB .yads_ad_pc_rank .yads_ad_info a,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info a,.pFymB .yads_ad_pc .yads_ad_info_res_s a,.pFymB .yads_ad_pc_res_s .yads_ad_info_res_s a,.pFymB .yads_ad_pc_rank .yads_ad_info_res_s a,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info_res_s a{padding:4px;color:#666666;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_info a:hover,.pFymB .yads_ad_pc_res_s .yads_ad_info a:hover,.pFymB .yads_ad_pc_rank .yads_ad_info a:hover,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info a:hover,.pFymB .yads_ad_pc .yads_ad_info_res_s a:hover,.pFymB .yads_ad_pc_res_s .yads_ad_info_res_s a:hover,.pFymB .yads_ad_pc_rank .yads_ad_info_res_s a:hover,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info_res_s a:hover{color:#666666;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_info a:hover span,.pFymB .yads_ad_pc_res_s .yads_ad_info a:hover span,.pFymB .yads_ad_pc_rank .yads_ad_info a:hover span,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info a:hover span,.pFymB .yads_ad_pc .yads_ad_info_res_s a:hover span,.pFymB .yads_ad_pc_res_s .yads_ad_info_res_s a:hover span,.pFymB .yads_ad_pc_rank .yads_ad_info_res_s a:hover span,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info_res_s a:hover span{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_info a img,.pFymB .yads_ad_pc_res_s .yads_ad_info a img,.pFymB .yads_ad_pc_rank .yads_ad_info a img,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info a img,.pFymB .yads_ad_pc .yads_ad_info_res_s a img,.pFymB .yads_ad_pc_res_s .yads_ad_info_res_s a img,.pFymB .yads_ad_pc_rank .yads_ad_info_res_s a img,.pFymB .yads_ad_pc_rank_res_s .yads_ad_info_res_s a img{vertical-align:top;}/*!sc*/
# .pFymB .yads_ad_pc_rank a.yads_ad_item:hover .yads_ad_title,.pFymB .yads_ad_pc_rank_res_s a.yads_ad_item:hover .yads_ad_title,.pFymB .yads_ad_pc_rank a.yads_ad_item_res_s:hover .yads_ad_title,.pFymB .yads_ad_pc_rank_res_s a.yads_ad_item_res_s:hover .yads_ad_title,.pFymB .yads_ad_pc_rank a.yads_ad_item:hover .yads_ad_desc,.pFymB .yads_ad_pc_rank_res_s a.yads_ad_item:hover .yads_ad_desc,.pFymB .yads_ad_pc_rank a.yads_ad_item_res_s:hover .yads_ad_desc,.pFymB .yads_ad_pc_rank_res_s a.yads_ad_item_res_s:hover .yads_ad_desc{color:#CC3434;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .pFymB .yads_ad_pc_rank .yads_ad_item,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item,.pFymB .yads_ad_pc_rank .yads_ad_item_res_s,.pFymB .yads_ad_pc_rank_res_s .yads_ad_item_res_s{padding:8px 0 24px 30px;}/*!sc*/
# .pFymB .yads_ad_pc_rank .yads_ad_title::before,.pFymB .yads_ad_pc_rank_res_s .yads_ad_title::before,.pFymB .yads_ad_pc_rank .yads_ad_title_res_s::before,.pFymB .yads_ad_pc_rank_res_s .yads_ad_title_res_s::before{position:absolute;top:8px;left:0;width:30px;font-size:0.8749999999999999rem;font-weight:bold;line-height:20px;color:#333333;text-align:center;-webkit-text-decoration:none;text-decoration:none;vertical-align:middle;content:'PR';}/*!sc*/
# .pFymB .comment .yads_ad_pc_rank .yads_ad_item,.pFymB .comment .yads_ad_pc_rank_res_s .yads_ad_item,.pFymB .comment .yads_ad_pc_rank .yads_ad_item_res_s,.pFymB .comment .yads_ad_pc_rank_res_s .yads_ad_item_res_s{padding:8px 0 24px 50px;}/*!sc*/
# .pFymB .comment .yads_ad_pc_rank .yads_ad_title::before,.pFymB .comment .yads_ad_pc_rank_res_s .yads_ad_title::before,.pFymB .comment .yads_ad_pc_rank .yads_ad_title_res_s::before,.pFymB .comment .yads_ad_pc_rank_res_s .yads_ad_title_res_s::before{width:50px;}/*!sc*/
# .pFymB .yads_ad_pc .yads_ad_title::before,.pFymB .yads_ad_pc_res_s .yads_ad_title::before,.pFymB .yads_ad_pc .yads_ad_title_res_s::before,.pFymB .yads_ad_pc_res_s .yads_ad_title_res_s::before{display:inline-block;padding:0 6px;margin-right:3px;font-size:0.6875rem;line-height:14px;color:#fff;vertical-align:middle;content:'PR';background:#717171;}/*!sc*/
# .pFymB .rma_responsive_small{margin-bottom:16px;border-bottom:1px solid rgb(225 225 225);}/*!sc*/
# .pFymB .rma_responsive_small .rma_header{padding:4px;font-size:0.8749999999999999rem;font-weight:bold;border-bottom:1px solid rgb(225 225 225);}/*!sc*/
# .pFymB .rma_responsive_small .rma_click_area a{display:block;padding:8px 0;}/*!sc*/
# .pFymB .rma_responsive_small .rma_click_area a:hover{-webkit-text-decoration:none;text-decoration:none;background:#EAEEF2;}/*!sc*/
# .pFymB .rma_responsive_small .rma_click_area a:hover .rma_title{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .pFymB .rma_responsive_small .rma_click_area a::after{content:'';clear:both;display:block;}/*!sc*/
# .pFymB .rma_responsive_small .rma_info{line-height:1.3;}/*!sc*/
# .pFymB .rma_responsive_small .rma_img{float:right;width:60px;height:60px;margin-left:10px;background-color:#EFEFEF;background-repeat:no-repeat;background-size:contain;}/*!sc*/
# .pFymB .rma_responsive_small .rma_title{display:inline;font-size:0.8125rem;}/*!sc*/
# .pFymB .rma_responsive_small .rma_adv{display:block;padding-top:4px;font-size:0.7499999999999999rem;color:#666666;}/*!sc*/
# .pFymB .rma_responsive_small a:hover .rma_adv{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .pFymB .rma_responsive_small .rma_footer{display:none;}/*!sc*/
# .pFymB .yads_ad_pc_feed,.pFymB .yads_ad_pc_feed_res_s,.pFymB .yads_ad_pc_feed_res_large{position:relative;}/*!sc*/
# .pFymB .yads_ad_pc_feed a.yads_ad_item:hover,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item:hover,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item:hover,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_s:hover,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_s:hover,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_s:hover,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_large:hover,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_large:hover,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_large:hover{background-color:#F9F9F9;}/*!sc*/
# .pFymB .yads_ad_pc_feed a.yads_ad_item:hover .yads_ad_title,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item:hover .yads_ad_title,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item:hover .yads_ad_title,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_s:hover .yads_ad_title,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_s:hover .yads_ad_title,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_s:hover .yads_ad_title,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_large:hover .yads_ad_title,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_large:hover .yads_ad_title,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_large:hover .yads_ad_title,.pFymB .yads_ad_pc_feed a.yads_ad_item:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_s:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_s:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_s:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_large:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_large:hover .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_large:hover .yads_ad_desc{color:#CC3434;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .pFymB .yads_ad_pc_feed a.yads_ad_item:visited,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item:visited,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item:visited,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_s:visited,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_s:visited,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_s:visited,.pFymB .yads_ad_pc_feed a.yads_ad_item_res_large:visited,.pFymB .yads_ad_pc_feed_res_s a.yads_ad_item_res_large:visited,.pFymB .yads_ad_pc_feed_res_large a.yads_ad_item_res_large:visited{color:#663399;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:12px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_img,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_img{position:relative;margin-right:8px;position:relative;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_img::after,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_img::after,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_img::after,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_img::after,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_img::after,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_img::after{position:absolute;top:0;left:0;box-sizing:border-box;display:block;width:80px;height:80px;content:'';border:solid 1px rgba(0,0,0,0.06);}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_img img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_img img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_img img,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_img img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_img img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_img img{max-width:80px;max-height:80px;vertical-align:middle;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_inner_2,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_inner_2,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_inner_2,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_inner_2,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_inner_2,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_inner_2,.pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_inner_2_res_s,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_inner_2_res_s,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_inner_2_res_s,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_inner_2_res_s,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_inner_2_res_s,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_inner_2_res_s{-webkit-flex:1;-ms-flex:1;flex:1;margin-bottom:14px;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_title,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_title,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_title,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_title,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_title,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_title{display:inline;line-height:1.3;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_desc,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_desc,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_desc{position:relative;display:inline;padding:0 0 0 4px;line-height:1.3;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_desc::before,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_desc::before,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_desc::before,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_desc::before,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_desc::before,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_desc::before{display:inline-block;padding:0 4px;content:'|';}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item .yads_ad_adv,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item .yads_ad_adv,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item .yads_ad_adv,.pFymB .yads_ad_pc_feed .yads_ad_item_res_s .yads_ad_adv,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_s .yads_ad_adv,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_s .yads_ad_adv{margin-top:4px;font-size:0.7499999999999999rem;color:#949494;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:12px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large .yads_ad_img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large .yads_ad_img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large .yads_ad_img{position:relative;margin-right:8px;position:relative;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large .yads_ad_img::after,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large .yads_ad_img::after,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large .yads_ad_img::after{position:absolute;top:0;left:0;box-sizing:border-box;display:block;width:200px;height:105px;content:'';border:solid 1px rgba(0,0,0,0.06);}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large .yads_ad_img img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large .yads_ad_img img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large .yads_ad_img img{max-width:200px;max-height:105px;vertical-align:middle;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large .yads_ad_inner_2_res_large,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large .yads_ad_inner_2_res_large,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large .yads_ad_inner_2_res_large{-webkit-flex:1;-ms-flex:1;flex:1;margin-bottom:14px;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large .yads_ad_title,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large .yads_ad_title,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large .yads_ad_title{display:inline;line-height:1.3;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_item_res_large .yads_ad_adv,.pFymB .yads_ad_pc_feed_res_s .yads_ad_item_res_large .yads_ad_adv,.pFymB .yads_ad_pc_feed_res_large .yads_ad_item_res_large .yads_ad_adv{margin-top:4px;font-size:0.7499999999999999rem;color:#949494;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_info,.pFymB .yads_ad_pc_feed_res_s .yads_ad_info,.pFymB .yads_ad_pc_feed_res_large .yads_ad_info{position:absolute;right:12px;bottom:12px;text-align:right;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_info a,.pFymB .yads_ad_pc_feed_res_s .yads_ad_info a,.pFymB .yads_ad_pc_feed_res_large .yads_ad_info a{padding:0;font-size:0.7499999999999999rem;color:#666666;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_info a:hover,.pFymB .yads_ad_pc_feed_res_s .yads_ad_info a:hover,.pFymB .yads_ad_pc_feed_res_large .yads_ad_info a:hover{color:#666666;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .pFymB .yads_ad_pc_feed .yads_ad_info img,.pFymB .yads_ad_pc_feed_res_s .yads_ad_info img,.pFymB .yads_ad_pc_feed_res_large .yads_ad_info img{vertical-align:middle;}/*!sc*/
# data-styled.g68[id="sc-1hyvns6-0"]{content:"pFymB,"}/*!sc*/
# .eEMpfR{margin-bottom:16px;min-height:250px;}/*!sc*/
# .bxxxoA{margin-bottom:16px;margin-top:-16px;}/*!sc*/
# data-styled.g69[id="sc-1hyvns6-1"]{content:"eEMpfR,bxxxoA,"}/*!sc*/
# .NusEp{display:inline-block;width:27px;height:12px;font-size:0;vertical-align:middle;background-size:27px 12px;background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/all/images/ico_new.svg);}/*!sc*/
# data-styled.g70[id="sc-12pq9o3-0"]{content:"NusEp,"}/*!sc*/
# .qtBfN{display:block;width:var(--thumbnail-width,auto);height:var(--thumbnail-height,auto);}/*!sc*/
# .qtBfN .riff-Thumbnail__root{display:block;width:100%;height:100%;}/*!sc*/
# .qtBfN .riff-Thumbnail__videoInformation{padding:2px 4px;}/*!sc*/
# .qtBfN .riff-Thumbnail__videoInformation svg{width:11px;height:11px;}/*!sc*/
# .qtBfN .riff-Thumbnail__videoInformation .riff-text-x-small{font-family:Helvetica;font-size:11px;line-height:11px;}/*!sc*/
# data-styled.g71[id="sc-1e8zc9k-0"]{content:"qtBfN,"}/*!sc*/
# .da-DOaQ{line-height:1.3;border-bottom:solid 1px #E1E1E1;}/*!sc*/
# data-styled.g72[id="sc-1t7ra5j-0"]{content:"da-DOaQ,"}/*!sc*/
# .RiieN{margin-left:8px;}/*!sc*/
# data-styled.g74[id="sc-1t7ra5j-2"]{content:"RiieN,"}/*!sc*/
# .lfylZJ{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g75[id="sc-1t7ra5j-3"]{content:"lfylZJ,"}/*!sc*/
# .hPBaAq{display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:30px;font-family:Arial,Helvetica,sans-serif;font-size:1.125rem;font-weight:bold;color:#333333;text-align:center;}/*!sc*/
# data-styled.g76[id="sc-1t7ra5j-4"]{content:"hPBaAq,"}/*!sc*/
# .jRyLYQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# data-styled.g77[id="sc-1t7ra5j-5"]{content:"jRyLYQ,"}/*!sc*/
# .hhriyT{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g78[id="sc-1t7ra5j-6"]{content:"hhriyT,"}/*!sc*/
# .casbUp{padding:0 0 4px;font-size:0.8125rem;}/*!sc*/
# data-styled.g79[id="sc-1t7ra5j-7"]{content:"casbUp,"}/*!sc*/
# .bVxZvL{font-size:0.7499999999999999rem;color:#949494;}/*!sc*/
# data-styled.g80[id="sc-1t7ra5j-8"]{content:"bVxZvL,"}/*!sc*/
# .dIJJqB{margin-right:4px;}/*!sc*/
# data-styled.g81[id="sc-1t7ra5j-9"]{content:"dIJJqB,"}/*!sc*/
# .cfHAOL{display:inline-block;margin-right:4px;}/*!sc*/
# data-styled.g82[id="sc-1t7ra5j-10"]{content:"cfHAOL,"}/*!sc*/
# .bppoEc{display:block;padding:8px 0;}/*!sc*/
# .bppoEc:visited{color:#663399;}/*!sc*/
# .bppoEc:hover{-webkit-text-decoration:none;text-decoration:none;background-color:#EAEEF2;}/*!sc*/
# .bppoEc:hover .sc-1t7ra5j-7{color:#CC3434;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g83[id="sc-1t7ra5j-11"]{content:"bppoEc,"}/*!sc*/
# .kxTIGi{padding:4px;font-size:0.8749999999999999rem;font-weight:bold;border-bottom:1px solid #E1E1E1;}/*!sc*/
# data-styled.g84[id="sc-1f41srm-0"]{content:"kxTIGi,"}/*!sc*/
# .dfklIm:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g85[id="sc-1f41srm-1"]{content:"dfklIm,"}/*!sc*/
# .fXFpQz{padding:0 0 16px;}/*!sc*/
# data-styled.g86[id="sc-1f41srm-2"]{content:"fXFpQz,"}/*!sc*/
# .iqDjHO{width:300px;padding-top:12px;margin-left:16px;}/*!sc*/
# data-styled.g94[id="sc-g8avba-0"]{content:"iqDjHO,"}/*!sc*/
# .kPbGhF{position:-webkit-sticky;position:sticky;bottom:0;width:300px;}/*!sc*/
# data-styled.g95[id="sc-g8avba-1"]{content:"kPbGhF,"}/*!sc*/
# .cJsvrG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g96[id="sc-tdedwt-0"]{content:"cJsvrG,"}/*!sc*/
# .jjOXhR{position:relative;font-size:0.9375rem;border-bottom:1px dotted #E1E1E1;}/*!sc*/
# .cqLLKa{position:relative;font-size:0.9375rem;border-bottom:1px dotted #E1E1E1;}/*!sc*/
# .cqLLKa::before,.cqLLKa::after{position:absolute;top:50%;width:0;height:0;margin-top:-8px;content:'';border:8px solid transparent;}/*!sc*/
# .cqLLKa::before{right:-17px;border-right:10px solid #E1E1E1;}/*!sc*/
# .cqLLKa::after{right:-18px;border-right:10px solid #FFFFFF;}/*!sc*/
# data-styled.g98[id="sc-1nhdoj2-0"]{content:"jjOXhR,cqLLKa,"}/*!sc*/
# .hKGArG{position:relative;display:block;padding:6px 0px 6px 15px;}/*!sc*/
# .hKGArG:visited{color:#663399;}/*!sc*/
# .hKGArG:hover{color:#CC3434;}/*!sc*/
# .hKGArG::before{position:absolute;top:50%;left:5px;display:block;width:4px;height:4px;margin-top:-2px;content:'';background-color:#E1E1E1;border-radius:2px;}/*!sc*/
# data-styled.g99[id="sc-1nhdoj2-1"]{content:"hKGArG,"}/*!sc*/
# .rpOpw{display:inline-block;margin-left:4px;font-size:0;vertical-align:middle;}/*!sc*/
# data-styled.g101[id="sc-1nhdoj2-3"]{content:"rpOpw,"}/*!sc*/
# .ktXjuF{display:block;padding:8px 0;font-size:0.8749999999999999rem;font-weight:bold;}/*!sc*/
# data-styled.g103[id="sc-18b2wkl-0"]{content:"ktXjuF,"}/*!sc*/
# .gClYrK:only-child{margin-left:auto;}/*!sc*/
# .gClYrK:only-child .sc-18b2wkl-0{font-weight:normal;}/*!sc*/
# data-styled.g104[id="sc-18b2wkl-1"]{content:"gClYrK,"}/*!sc*/
# .PhVco{opacity:0;visibility:hidden;-webkit-transition:all 0.5s;transition:all 0.5s;}/*!sc*/
# data-styled.g108[id="sc-sh60th-0"]{content:"PhVco,"}/*!sc*/
# .dDoAio{padding:16px;border-top:1px solid #F0F0F0;}/*!sc*/
# data-styled.g123[id="sc-10wa6pi-0"]{content:"dDoAio,"}/*!sc*/
# .bhHWlj{display:block;width:100%;padding:16px 0;font-size:0.8749999999999999rem;font-weight:bold;color:#444444;-webkit-text-decoration:none;text-decoration:none;background-color:#FFFFFF;border:solid 1px #BBBBBB;border-radius:4px;}/*!sc*/
# .bhHWlj:hover{background-color:#F9F9F9;}/*!sc*/
# data-styled.g124[id="sc-10wa6pi-1"]{content:"bhHWlj,"}/*!sc*/
# .fDWyyQ{padding:8px;font-weight:bold;border-top:1px solid #E1E1E1;}/*!sc*/
# data-styled.g177[id="sc-10ppf8a-0"]{content:"fDWyyQ,"}/*!sc*/
# .jatlWr{margin-left:auto;}/*!sc*/
# data-styled.g1049[id="sc-1auydty-0"]{content:"jatlWr,"}/*!sc*/
# .fFWOw{display:block;padding:8px 0;font-size:0.8749999999999999rem;}/*!sc*/
# .fFWOw:hover{color:#CC3434;}/*!sc*/
# data-styled.g1050[id="sc-1auydty-1"]{content:"fFWOw,"}/*!sc*/
# .MqSUc{width:232px;padding-left:12px;font-size:0.8749999999999999rem;}/*!sc*/
# data-styled.g1051[id="sc-g6tbt6-0"]{content:"MqSUc,"}/*!sc*/
# .hSeUGq{display:block;}/*!sc*/
# .hSeUGq:visited{color:#663399;}/*!sc*/
# .hSeUGq:hover{color:#CC3434;}/*!sc*/
# data-styled.g1052[id="sc-g6tbt6-1"]{content:"hSeUGq,"}/*!sc*/
# .fcaMoC{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;width:220px;height:220px;margin-bottom:8px;background-repeat:no-repeat;background-size:contain;background-position:center center;background-color:#EFEFEF;}/*!sc*/
# .fcaMoC::after{position:absolute;top:0;left:0;box-sizing:border-box;display:block;width:220px;height:220px;content:'';border:solid 1px rgba(0,0,0,0.06);}/*!sc*/
# data-styled.g1053[id="sc-g6tbt6-2"]{content:"fcaMoC,"}/*!sc*/
# .flbIlF{padding:8px 16px 16px;}/*!sc*/
# data-styled.g1056[id="sc-1d6xg0e-0"]{content:"flbIlF,"}/*!sc*/
# .gRVZTY{-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);height:1px;overflow:hidden;position:absolute !important;width:1px;}/*!sc*/
# data-styled.g1057[id="sc-1d6xg0e-1"]{content:"gRVZTY,"}/*!sc*/
# .eYVVxH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g1058[id="sc-1d6xg0e-2"]{content:"eYVVxH,"}/*!sc*/
# .eUEpFI{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;min-width:368px;padding-right:16px;line-height:1.15;border-right:1px solid #E1E1E1;}/*!sc*/
# data-styled.g1059[id="sc-1d6xg0e-3"]{content:"eUEpFI,"}/*!sc*/
# .hrGDZv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:469px;height:263.8125px;padding:8px;font-weight:bold;color:#333333;text-align:center;background-color:#F0F0F0;border:1px solid #E1E1E1;border-radius:4px;}/*!sc*/
# data-styled.g1175[id="sc-kk13qt-0"]{content:"hrGDZv,"}/*!sc*/
# .bVbESI{width:100%;font-size:0.8749999999999999rem;font-weight:bold;text-align:center;}/*!sc*/
# .bVbESI:hover{opacity:0.8;}/*!sc*/
# data-styled.g2142[id="sc-1dl9207-0"]{content:"bVbESI,"}/*!sc*/
# .kevUbK{display:block;width:100%;height:0;padding-top:calc(9 / 16 * 100%);overflow:hidden;background-repeat:no-repeat;background-position:center center;background-size:contain;background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/all/images/logo_live_nnn.png);}/*!sc*/
# .eJfwMB{display:block;width:100%;height:0;padding-top:calc(9 / 16 * 100%);overflow:hidden;background-repeat:no-repeat;background-position:center center;background-size:contain;background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/all/images/logo_live_jnn_v202204.png);}/*!sc*/
# data-styled.g2145[id="sc-1dl9207-3"]{content:"kevUbK,eJfwMB,"}/*!sc*/
# .fSPfiT{border:1px solid rgb(0 0 0 / 20%);-webkit-transition:-webkit-transform 0.3s ease-out;-webkit-transition:transform 0.3s ease-out;transition:transform 0.3s ease-out;-webkit-transform:scale(0.9) rotate(0.001deg);-ms-transform:scale(0.9) rotate(0.001deg);transform:scale(0.9) rotate(0.001deg);}/*!sc*/
# data-styled.g2146[id="sc-1dl9207-4"]{content:"fSPfiT,"}/*!sc*/
# .hqCYfZ{padding:0 0 16px;border-top:1px solid #E1E1E1;}/*!sc*/
# data-styled.g2147[id="sc-qhzeq4-0"]{content:"hqCYfZ,"}/*!sc*/
# .jqfyNy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:12px 16px;}/*!sc*/
# data-styled.g2148[id="sc-qhzeq4-1"]{content:"jqfyNy,"}/*!sc*/
# .bgbiop{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;font-weight:bold;}/*!sc*/
# data-styled.g2149[id="sc-qhzeq4-2"]{content:"bgbiop,"}/*!sc*/
# .gEkxEP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:0 16px 16px;}/*!sc*/
# data-styled.g2151[id="sc-qhzeq4-4"]{content:"gEkxEP,"}/*!sc*/
# .CGKKJ{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;gap:28px;width:138px;}/*!sc*/
# data-styled.g2153[id="sc-qhzeq4-6"]{content:"CGKKJ,"}/*!sc*/
# .isZSxt{cursor:-webkit-grab;cursor:-moz-grab;cursor:grab;}/*!sc*/
# data-styled.g2154[id="sc-1kwbdbu-0"]{content:"isZSxt,"}/*!sc*/
# .kVSpqs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g2155[id="sc-11s5pce-0"]{content:"kVSpqs,"}/*!sc*/
# .xqVIP{display:block;width:20px;height:20px;margin-right:8px;font-family:Arial,Helvetica,sans-serif;font-size:15px;font-weight:bold;color:#fff;text-align:center;background-color:#f14b43;border-radius:2px;}/*!sc*/
# .gRkHmM{display:block;width:20px;height:20px;margin-right:8px;font-family:Arial,Helvetica,sans-serif;font-size:15px;font-weight:bold;color:#fff;text-align:center;background-color:#DD6214;border-radius:2px;}/*!sc*/
# .gCqQfY{display:block;width:20px;height:20px;margin-right:8px;font-family:Arial,Helvetica,sans-serif;font-size:15px;font-weight:bold;color:#fff;text-align:center;background-color:#B97904;border-radius:2px;}/*!sc*/
# .bGCgCH{display:block;width:20px;height:20px;margin-right:8px;font-family:Arial,Helvetica,sans-serif;font-size:15px;font-weight:bold;color:#6A6A6A;text-align:center;background-color:#EBEBEB;border-radius:2px;}/*!sc*/
# data-styled.g2156[id="sc-11s5pce-1"]{content:"xqVIP,gRkHmM,gCqQfY,bGCgCH,"}/*!sc*/
# .hnbwbv{margin-right:8px;font-size:16px;line-height:20px;}/*!sc*/
# .hnbwbp{margin-right:2px;font-size:16px;line-height:20px;}/*!sc*/
# data-styled.g2157[id="sc-11s5pce-2"]{content:"hnbwbv,hnbwbp,"}/*!sc*/
# .bfZUKZ{margin-right:4px;color:#F76564;vertical-align:text-bottom;}/*!sc*/
# data-styled.g2158[id="sc-11s5pce-3"]{content:"bfZUKZ,"}/*!sc*/
# .kwQDyP{font-size:11px;color:#949494;}/*!sc*/
# data-styled.g2159[id="sc-11s5pce-4"]{content:"kwQDyP,"}/*!sc*/
# .ePAPxZ{display:block;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ePAPxZ:not(:nth-last-of-type(-n + 3)){margin-right:40px;}/*!sc*/
# .ePAPxZ:not(:nth-of-type(3n)){margin-bottom:12px;}/*!sc*/
# .ePAPxZ:hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ePAPxZ:hover .sc-11s5pce-2{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g2160[id="sc-11s5pce-5"]{content:"ePAPxZ,"}/*!sc*/
# .bqlnHf{padding:0 16px;border-top:1px solid #E1E1E1;}/*!sc*/
# data-styled.g2161[id="sc-8tpdda-0"]{content:"bqlnHf,"}/*!sc*/
# .dSnkKt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:10px 0;}/*!sc*/
# data-styled.g2162[id="sc-8tpdda-1"]{content:"dSnkKt,"}/*!sc*/
# .fWcWRL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g2163[id="sc-8tpdda-2"]{content:"fWcWRL,"}/*!sc*/
# .llBNdi{display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:20px;height:20px;margin:auto;margin-right:4px;background-image:url(https://s.yimg.jp/images/news-web/versions/20251110-72f866c/sp/images/icon_cmttl.png);background-repeat:no-repeat;background-position:center;background-size:contain;}/*!sc*/
# data-styled.g2164[id="sc-8tpdda-3"]{content:"llBNdi,"}/*!sc*/
# .bretQi{font-size:1rem;font-weight:bold;}/*!sc*/
# data-styled.g2165[id="sc-8tpdda-4"]{content:"bretQi,"}/*!sc*/
# .jhhoBV{margin-top:auto;font-size:14px;}/*!sc*/
# data-styled.g2166[id="sc-8tpdda-5"]{content:"jhhoBV,"}/*!sc*/
# .kqzTSZ{position:relative;margin-top:5px;margin-bottom:16px;}/*!sc*/
# data-styled.g2167[id="sc-8tpdda-6"]{content:"kqzTSZ,"}/*!sc*/
# .iqbvWJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:column wrap;-ms-flex-flow:column wrap;flex-flow:column wrap;height:84px;margin-right:40px;overflow-x:scroll;overflow-y:hidden;white-space:nowrap;-ms-overflow-style:none;-webkit-scrollbar-width:none;-moz-scrollbar-width:none;-ms-scrollbar-width:none;scrollbar-width:none;}/*!sc*/
# .iqbvWJ::-webkit-scrollbar{display:none;}/*!sc*/
# data-styled.g2168[id="sc-8tpdda-7"]{content:"iqbvWJ,"}/*!sc*/
# .hHUYjG{fill:#666666;}/*!sc*/
# data-styled.g2170[id="sc-8tpdda-9"]{content:"hHUYjG,"}/*!sc*/
# .crKwYl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:30px;height:30px;border-radius:15px;}/*!sc*/
# .crKwYl:hover{background-color:#F9F9F9;}/*!sc*/
# data-styled.g2171[id="sc-8tpdda-10"]{content:"crKwYl,"}/*!sc*/
# .ezyaRU{position:absolute;top:0;z-index:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:76px;height:100%;right:0;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;background-image:linear-gradient(to right,rgb(255 255 255 / 0%),#fff 50%);}/*!sc*/
# data-styled.g2172[id="sc-8tpdda-11"]{content:"ezyaRU,"}/*!sc*/
# </style></head><body><div class="sc-1ofrwxp-0 iMLphd tracked_mods" id="wrapper"><header class="sc-qi0cuu-0 kVywcd"><h1 class="sc-qi0cuu-1 gInhqu">Yahoo!ニュース</h1><noscript><div class="sc-wyepu0-0 eDNJiS"><div class="sc-wyepu0-1 bEDLqp"><a class="sc-wyepu0-3 cEtrIL" href="/"><img alt="Yahoo!ニュース" class="sc-wyepu0-2 kZUXoC" src="https://s.yimg.jp/c/logo/f/2.0/news_r_34_2x.png"/></a></div><div><a class="sc-wyepu0-4 jviMvu" href="https://www.yahoo.co.jp/">Yahoo! JAPAN</a><a class="sc-wyepu0-4 jviMvu" href="https://support.yahoo-net.jp/PccNews/s/">ヘルプ</a></div></div><style>#yjnEmg{display:none;}</style></noscript><div class="sc-qccjvf-0 NxFLs" id="yjnEmg"><iframe id="TEMPLA_MH" src="https://s.yimg.jp/images/templa/mhdemg/v2/static_mhd.html" style="width:100%;height:88px;border-width:0;vertical-align:bottom;margin:0 auto 10px"></iframe></div><script>
#               YAHOO = window.YAHOO || {};
#               YAHOO.JP = YAHOO.JP || {};
#               YAHOO.JP.templa = YAHOO.JP.templa || {};
#               YAHOO.JP.templa.param = {"device_id":"pc","domain":"news","mh_logo_width":206,"mh_logo_height":34,"mh_logo_alt":"Yahoo!ニュース","mh_login_done":"https://news.yahoo.co.jp/"}
#               </script><script defer="" src="https://s.yimg.jp/images/templa/mhdemg/v2/templa.min.js"></script><nav class="sc-icb4tv-0 ijuFgx"><div id="gnavi"><div class="sc-icb4tv-1 hdfiKA"><div id="searchBoxWrap-header"><form action="/search" method="get"><div class="sc-1a5izri-0 bfTAVr"><div class="sc-1a5izri-1 GIdOR"><div class="sc-1a5izri-2 erlYiR"><input aria-label="検索したいキーワードを入力してください" autocomplete="off" class="sc-1a5izri-3 jaNIIv" name="p" placeholder="キーワードを入力" type="text" value=""/><input name="ei" type="hidden" value="utf-8"/></div><div class="sc-1a5izri-4 lplCjf"><button aria-label="検索ボタン" class="sc-1a5izri-5 igZwvK" type="submit" value="検索"><svg class="sc-1a5izri-6 dONbjh riff-text-current" fill="currentColor" focusable="false" height="18" viewbox="0 0 48 48" width="18"><path clip-rule="evenodd" d="M21 32c-6.075 0-11-4.925-11-11s4.925-11 11-11 11 4.925 11 11-4.925 11-11 11Zm20.414 6.586-8.499-8.499A14.919 14.919 0 0 0 36 21c0-8.284-6.716-15-15-15-8.284 0-15 6.716-15 15 0 8.284 6.716 15 15 15a14.91 14.91 0 0 0 9.086-3.085l8.5 8.499a2 2 0 1 0 2.828-2.828Z" fill-rule="evenodd"></path></svg></button></div></div></div></form></div><ul class="sc-icb4tv-2 eSeojU"><li class="sc-1mps4g6-2 flgkZr"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:profnm;" href="https://news.yahoo.co.jp/users/me" rel="nofollow">マイページ</a></li><li class="sc-1mps4g6-2 iansBY"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:pur;" href="/purchase" rel="nofollow">購入履歴</a></li><li class="sc-1mps4g6-2 lfapxT"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:set;" href="https://news.yahoo.co.jp/settings/blocked-users" rel="nofollow"><svg aria-label="設定" class="sc-1mps4g6-1 gULBmj riff-text-current" fill="currentColor" focusable="false" height="20" role="img" viewbox="0 0 48 48" width="20"><path clip-rule="evenodd" d="M30.65 24a6.65 6.65 0 1 1-13.3 0 6.65 6.65 0 0 1 13.3 0Zm11.445-3.548-3.653-1.174a14.99 14.99 0 0 0-.895-2.145l1.756-3.42c.239-.466.131-1.148-.238-1.518l-3.262-3.261c-.369-.37-1.051-.477-1.516-.239l-3.421 1.757a15.033 15.033 0 0 0-2.145-.894l-1.175-3.654c-.16-.497-.717-.904-1.24-.904h-4.614c-.522 0-1.08.407-1.24.904l-1.174 3.654c-.743.242-1.457.545-2.145.894l-3.42-1.757c-.466-.238-1.149-.131-1.518.239l-3.262 3.262c-.369.369-.476 1.052-.238 1.517l1.757 3.421c-.35.687-.653 1.401-.895 2.144l-3.653 1.175c-.497.16-.904.718-.904 1.24v4.615c0 .522.407 1.08.904 1.24l3.653 1.174c.242.743.545 1.457.895 2.144l-1.757 3.422c-.238.465-.131 1.148.238 1.517l3.263 3.261c.369.37 1.052.477 1.517.238l3.42-1.756c.688.349 1.402.652 2.145.894l1.175 3.654c.16.497.718.904 1.24.904h4.614c.523 0 1.08-.407 1.24-.904l1.174-3.654a15.161 15.161 0 0 0 2.146-.894l3.421 1.756c.465.238 1.147.131 1.516-.239l3.262-3.261c.369-.369.477-1.052.237-1.517l-1.756-3.42c.35-.688.653-1.402.896-2.145l3.652-1.175c.497-.16.905-.718.905-1.24v-4.615c0-.522-.408-1.08-.905-1.24Z" fill-rule="evenodd"></path></svg></a></li></ul></div><ul class="sc-icb4tv-4 fvOJzU"><li class="sc-1mps4g6-2 hkMhsE"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:hl;" href="/">トップ</a></li><li class="sc-1mps4g6-2 kMKDnI"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:fl;" href="/flash">速報</a></li><li class="sc-1mps4g6-2 kMKDnI"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:mv;" href="/live">ライブ</a></li><li class="sc-1mps4g6-2 kMKDnI"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:by;" href="/expert">エキスパート</a></li><li class="sc-1mps4g6-2 kMKDnI"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:orgn;" href="https://news.yahoo.co.jp/original/">オリジナル</a></li><li class="sc-1mps4g6-2 kMKDnI"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:poll;" href="/polls">みんなの意見</a></li><li class="sc-1mps4g6-2 kMKDnI"><a class="sc-1mps4g6-0 gJIhOe" data-cl-params="_cl_vmodule:gnavi;_cl_link:accrank;" h ...
#           window.ualcmds = window.ualcmds || [];
#           window.ual = window.ual || function() {
#             ualcmds.push(arguments);
#           };
#           ual('config', 'token', '5ae7ece4-3b93-4890-8f24-ce16ddd756ed');
#           function hitPageView () {
#             ual('hit', 'pageview', {
#               service: 'news',
#               opttype: 'pc',
#
#
#               mtestid:'mfn_18800=ttlg1t1'
#               },
#               { flush: true }
#             );
#           };
#           if (document.prerendering) {
#             document.addEventListener('prerenderingchange', hitPageView, {
#               once: true
#             });
#           } else {
#             hitPageView();
#           }
#         </script></div><script src="https://s.yimg.jp/images/news-web/versions/20251110-72f866c/pc/js/top.js" type="text/javascript"></script></body></html>

# %%
# リスト2.1.19
# 必要な情報の抽出（Yahoo!ニュースのトップ HTML から記事タイトル候補を抽出して表示）
# --------------------------------------------------------------------------------
# 目的:
#   - BeautifulSoup の CSS セレクタ機能（.select）を用いて、特定のクラス名を持つ要素群を抽出し、
#     その可視テキストを標準出力へ列挙する。
#
# 背景・理論メモ:
#   - `.select(css_selector)` は CSS セレクタに一致する要素を **リスト** で返す（0件の場合は空リスト）。
#     セレクタ `.newsFeed_item_title` は「class='newsFeed_item_title' を持つ要素」を意味する。
#   - `.getText()` は `.get_text()` の別名で、要素配下の全テキストノードを連結して返す。
#     引数に `strip=True` 等を与えると前後空白を除去できるが、本スニペットでは **挙動を変えない** 方針のため未指定。
#   - 大規模サイトではクラス名が頻繁に変わる（A/Bテスト・デザイン刷新・難読化）ため、
#     セレクタが壊れて 0 件になる可能性がある点に注意。動的レンダリング要素は本手法では取得できないこともある。
#   - 可観測性と再現性の観点では、取得時の User-Agent・地域設定・取得時刻によって DOM が変わり得るため、
#     実運用ではメタ情報のログ化やフォールバックセレクタ（例: 見出しタグ 'h3 a' など）を併用すると堅牢性が上がる。
#   - 計算量は DOM ノード数を N とすると、おおまかに O(N) の走査。1ページ単位では現実的。

for title in contents.select(
    ".newsFeed_item_title"
):  # CSSクラス 'newsFeed_item_title' を持つ要素をすべて取得
    print(
        title.getText()
    )  # 要素配下のテキストを連結して出力（空白・改行は元HTML依存のまま）
